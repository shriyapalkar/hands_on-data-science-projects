# %% [markdown]
# <a href="https://colab.research.google.com/github/shriyapalkar/hands_on-data-science-projects/blob/main/Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
#express framework
import plotly.graph_objects as go
import seaborn as sns

# %%
df=pd.read_csv("/content/twitter_dataset.csv");
df
# Out:
#       Tweet_ID         Username  \
# 0            1          julie81
# 1            2    richardhester
# 2            3   williamsjoseph
# 3            4      danielsmary
# 4            5       carlwarren
# ...        ...              ...
# 9995      9996            ntate
# 9996      9997   garrisonjoshua
# 9997      9998  adriennejackson
# 9998      9999         kcarlson
# 9999     10000       vdickerson
#
#                                                    Text  Retweets  Likes  \
# 0     Party least receive say or single. Prevent pre...         2     25
# 1     Hotel still Congress may member staff. Media d...        35     29
# 2     Nice be her debate industry that year. Film wh...        51     25
# 3     Laugh explain situation career occur serious. ...        37     18
# 4     Involve sense former often approach government...        27     80
# ...                                                 ...       ...    ...
# ...

# %%
df.head()
df.tail()
# Out:
#       Tweet_ID         Username  \
# 9995      9996            ntate
# 9996      9997   garrisonjoshua
# 9997      9998  adriennejackson
# 9998      9999         kcarlson
# 9999     10000       vdickerson
#
#                                                    Text  Retweets  Likes  \
# 9995  Agree reflect military box ability ever hold. ...        81     86
# 9996  Born which push still. Degree sometimes contro...        73    100
# 9997  You day agent likely region. Teacher data mess...        10     62
# 9998  Guess without successful save. Particular natu...        21     60
# 9999  Body onto understand team about product beauti...        65     54
#
#                 Timestamp
# 9995  2023-01-15 11:46:20
# 9996  2023-05-06 00:46:54
# 9997  2023-02-27 14:55:08
# 9998  2023-01-09 16:09:35
# 9999  2023-04-19 01:35:56

# %%
df=pd.read_csv("/content/twitter_dataset.csv");
df
# Out:
#       Tweet_ID         Username  \
# 0            1          julie81
# 1            2    richardhester
# 2            3   williamsjoseph
# 3            4      danielsmary
# 4            5       carlwarren
# ...        ...              ...
# 9995      9996            ntate
# 9996      9997   garrisonjoshua
# 9997      9998  adriennejackson
# 9998      9999         kcarlson
# 9999     10000       vdickerson
#
#                                                    Text  Retweets  Likes  \
# 0     Party least receive say or single. Prevent pre...         2     25
# 1     Hotel still Congress may member staff. Media d...        35     29
# 2     Nice be her debate industry that year. Film wh...        51     25
# 3     Laugh explain situation career occur serious. ...        37     18
# 4     Involve sense former often approach government...        27     80
# ...                                                 ...       ...    ...
# ...

# %%
sns.scatterplot(x="Tweet_ID",y="Likes",data=df[:50])
# Out:
# <Axes: xlabel='Tweet_ID', ylabel='Likes'>

# %%
sns.scatterplot(x="Tweet_ID",y="Retweets",data=df[:50])
# Out:
# <Axes: xlabel='Tweet_ID', ylabel='Retweets'>

# %%
sns.lineplot(x="Tweet_ID",y="Likes",data=df[:50])
# Out:
# <Axes: xlabel='Tweet_ID', ylabel='Likes'>

# %%
sns.barplot(x="Likes",y="Retweets",data=df[:20])
# Out:
# <Axes: xlabel='Likes', ylabel='Retweets'>

# %%
figure=px.scatter(df[:200],x="Tweet_ID",y="Likes",size="Likes")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.histplot(df['Likes'])
# Out:
# <Axes: xlabel='Likes', ylabel='Count'>

# %%
sns.distplot(df["Likes"])
# Out:
# <ipython-input-26-30204494f071>:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='Likes', ylabel='Density'>
